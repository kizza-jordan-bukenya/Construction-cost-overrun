# %%
import pandas as pd

# %%
df = pd.read_csv('../data/construction_integrated_dataset_100k_v2.csv')
df
# Out:
#       Project_ID    Project_Type   Area  Floor_Count Structure_Type  \
# 0        P000001        Building  12505            3            SRC
# 1        P000002      Remodeling   2230           10            SRC
# 2        P000003  Infrastructure  25663            2          Steel
# 3        P000004  Infrastructure  73112            4          Steel
# 4        P000005        Building   9016            6          Steel
# ...          ...             ...    ...          ...            ...
# 99995    P099996      Remodeling   4380           16            SRC
# 99996    P099997      Remodeling   8545           11            SRC
# 99997    P099998  Infrastructure  66681            2             RC
# 99998    P099999        Building  16114           11      Composite
# 99999    P100000        Building   9697           12             RC
#
#       Contract_Type  Planned_Cost   Actual_Cost  Cost_Overrun  \
# 0      Design-Build   55933286985   62140707241      0.110979
# ...

# %%
df.shape
# Out:
# (100000, 24)

# %%
df.columns
# Out:
# Index(['Project_ID', 'Project_Type', 'Area', 'Floor_Count', 'Structure_Type',
#        'Contract_Type', 'Planned_Cost', 'Actual_Cost', 'Cost_Overrun',
#        'Planned_Duration', 'Actual_Duration', 'Schedule_Delay', 'Labor_Total',
#        'Equipment_Count', 'Resource_Utilization', 'Change_Order_Count',
#        'Change_Cost_Ratio', 'Defect_Count', 'Defect_Severity', 'Repair_Cost',
#        'Accident_Count', 'Risk_Level', 'Temperature', 'Rainfall'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Project_ID            100000 non-null  str
#  1   Project_Type          100000 non-null  str
#  2   Area                  100000 non-null  int64
#  3   Floor_Count           100000 non-null  int64
#  4   Structure_Type        100000 non-null  str
#  5   Contract_Type         100000 non-null  str
#  6   Planned_Cost          100000 non-null  int64
#  7   Actual_Cost           100000 non-null  int64
#  8   Cost_Overrun          100000 non-null  float64
#  9   Planned_Duration      100000 non-null  int64
#  10  Actual_Duration       100000 non-null  int64
#  11  Schedule_Delay        100000 non-null  float64
#  12  Labor_Total           100000 non-null  int64
#  13  Equipment_Count       100000 non-null  int64
#  14  Resource_Utilization  100000 non-null  float64
# ...

# %%
df[['Planned_Cost', 'Actual_Cost', 'Cost_Overrun']].head(10)
# Out:
#    Planned_Cost    Actual_Cost  Cost_Overrun
# 0   55933286985    62140707241      0.110979
# 1   10260857113    13237347066      0.290082
# 2  113835497352   143916641362      0.264251
# 3  327847107133   420747174798      0.283364
# 4   23487617527    27498457046      0.170764
# 5   50957629493    56848331462      0.115600
# 6    6629505830     8241569615      0.243165
# 7   53639681287    69284284370      0.291661
# 8  179705824846   238093505279      0.324907
# 9  838464668339  1114156043612      0.328805

# %%
df[['Planned_Cost', 'Actual_Cost', 'Cost_Overrun']].describe()
# Out:
#        Planned_Cost   Actual_Cost   Cost_Overrun
# count  1.000000e+05  1.000000e+05  100000.000000
# mean   8.755409e+10  1.092055e+11       0.245647
# std    1.411334e+11  1.798547e+11       0.100293
# min    8.339704e+08  1.172045e+09      -0.004922
# 25%    2.103780e+10  2.623637e+10       0.169837
# 50%    4.450006e+10  5.457965e+10       0.232759
# 75%    9.554641e+10  1.173589e+11       0.308961
# max    2.510927e+12  3.285051e+12       0.550000

# %%
df['Cost_Overrun'].value_counts().head(20)
# Out:
# Cost_Overrun
# 0.550000    699
# 0.177407      6
# 0.231655      5
# 0.168885      5
# 0.218334      5
# 0.214576      5
# 0.182788      5
# 0.213635      4
# 0.187935      4
# 0.182789      4
# 0.141642      4
# 0.221270      4
# 0.201801      4
# 0.289892      4
# 0.195876      4
# 0.289916      4
# 0.204639      4
# 0.154208      4
# 0.203131      4
# 0.323510      4
# Name: count, dtype: int64

# %%
df['Project_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                          count          mean           std           min  \
# Area                  100000.0  2.545422e+04  4.167471e+04  5.000000e+02
# Floor_Count           100000.0  1.039981e+01  7.730733e+00  1.000000e+00
# Planned_Cost          100000.0  8.755409e+10  1.411334e+11  8.339704e+08
# Actual_Cost           100000.0  1.092055e+11  1.798547e+11  1.172045e+09
# Cost_Overrun          100000.0  2.456471e-01  1.002928e-01 -4.922000e-03
# Planned_Duration      100000.0  2.889280e+02  1.896491e+02  9.000000e+01
# Actual_Duration       100000.0  3.368778e+02  2.234927e+02  8.600000e+01
# Schedule_Delay        100000.0  1.696609e-01  8.757441e-02 -5.634600e-02
# Labor_Total           100000.0  8.052547e+01  5.429230e+01  1.000000e+01
# Equipment_Count       100000.0  5.549020e+00  4.792401e+00  1.000000e+00
# Resource_Utilization  100000.0  7.279645e-01  1.264595e-01  4.000000e-01
# Change_Order_Count    100000.0  2.057150e+00  1.481191e+00  0.000000e+00
# ...

# %%
print("Project Types:")
print(df['Project_Type'].value_counts())

print("\nStructure Types:")
print(df['Structure_Type'].value_counts())

print("\nContract Types:")
print(df['Contract_Type'].value_counts())
# Out:
# Project Types:
# Project_Type
# Building          49934
# Infrastructure    25121
# Remodeling        24945
# Name: count, dtype: int64
#
# Structure Types:
# Structure_Type
# RC           29756
# Steel        20078
# Composite    15009
# SRC          14964
# Masonry      10144
# Concrete     10049
# Name: count, dtype: int64
#
# Contract Types:
# Contract_Type
# DBB             35012
# Design-Build    29941
# Turnkey         19957
# CM-at-Risk      15090
# Name: count, dtype: int64

# %%
features = [
    'Project_Type',
    'Area',
    'Floor_Count',
    'Structure_Type',
    'Contract_Type',
    'Planned_Cost',
    'Planned_Duration',
    'Labor_Total',
    'Equipment_Count',
    'Resource_Utilization',
    'Change_Order_Count',
    'Change_Cost_Ratio',
    'Defect_Count',
    'Defect_Severity',
    'Repair_Cost',
    'Accident_Count',
    'Risk_Level',
    'Temperature',
    'Rainfall'
]

target = 'Cost_Overrun'

# %%
df.select_dtypes(include='number').corr()['Cost_Overrun'].sort_values(ascending=False)
# Out:
# Cost_Overrun            1.000000
# Risk_Level              0.686981
# Schedule_Delay          0.681279
# Change_Cost_Ratio       0.585893
# Change_Order_Count      0.560437
# Accident_Count          0.479954
# Defect_Count            0.337656
# Rainfall                0.103240
# Repair_Cost             0.085677
# Defect_Severity         0.076518
# Actual_Cost             0.052739
# Actual_Duration         0.040382
# Area                    0.024539
# Planned_Cost            0.010172
# Temperature            -0.021979
# Equipment_Count        -0.026791
# Labor_Total            -0.032892
# Planned_Duration       -0.033606
# Resource_Utilization   -0.110756
# Floor_Count            -0.134857
# Name: Cost_Overrun, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df['Cost_Overrun'], bins=30)
plt.xlabel('Cost Overrun')
plt.ylabel('Number of Projects')
plt.title('Distribution of Construction Cost Overrun')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Risk_Level'], df['Cost_Overrun'], alpha=0.2)
plt.xlabel('Risk Level')
plt.ylabel('Cost Overrun')
plt.title('Risk Level vs Cost Overrun')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Schedule_Delay'], df['Cost_Overrun'], alpha=0.2)
plt.xlabel('Schedule Delay')
plt.ylabel('Cost Overrun')
plt.title('Schedule Delay vs Cost Overrun')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Change_Cost_Ratio'], df['Cost_Overrun'], alpha=0.2)
plt.xlabel('Change Cost Ratio')
plt.ylabel('Cost Overrun')
plt.title('Change Cost Ratio vs Cost Overrun')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Change_Order_Count'], df['Cost_Overrun'], alpha=0.2)
plt.xlabel('Change Order Count')
plt.ylabel('Cost Overrun')
plt.title('Change Order Count vs Cost Overrun')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Accident_Count'], df['Cost_Overrun'], alpha=0.2)
plt.xlabel('Accident Count')
plt.ylabel('Cost Overrun')
plt.title('Accident Count vs Cost Overrun')
plt.show()

# %%
df.groupby('Project_Type')['Cost_Overrun'].agg(['mean', 'median', 'count'])
# Out:
#                     mean    median  count
# Project_Type
# Building        0.201237  0.189142  49934
# Infrastructure  0.259342  0.249872  25121
# Remodeling      0.320754  0.313082  24945

# %%
df.groupby('Structure_Type')['Cost_Overrun'].agg(['mean', 'median', 'count']).sort_values('mean', ascending=False)
# Out:
#                     mean    median  count
# Structure_Type
# Concrete        0.246651  0.234237  10049
# Masonry         0.245937  0.232743  10144
# Composite       0.245866  0.232232  15009
# Steel           0.245656  0.232884  20078
# RC              0.245322  0.232839  29756
# SRC             0.245190  0.232119  14964

# %%
df.groupby('Contract_Type')['Cost_Overrun'].agg(
    ['mean', 'median', 'count']
).sort_values('mean', ascending=False)
# Out:
#                    mean    median  count
# Contract_Type
# DBB            0.277044  0.266394  35012
# Design-Build   0.233848  0.220009  29941
# Turnkey        0.233670  0.219782  19957
# CM-at-Risk     0.212052  0.197588  15090

# %%
X = df.drop(columns=[
    'Project_ID',
    'Actual_Cost',
    'Actual_Duration',
    'Schedule_Delay',
    'Cost_Overrun'
])

y = df['Cost_Overrun']

print("X shape:", X.shape)
print("y shape:", y.shape)
print("\nFeatures:")
print(X.columns.tolist())
# Out:
# X shape: (100000, 19)
# y shape: (100000,)
#
# Features:
# ['Project_Type', 'Area', 'Floor_Count', 'Structure_Type', 'Contract_Type', 'Planned_Cost', 'Planned_Duration', 'Labor_Total', 'Equipment_Count', 'Resource_Utilization', 'Change_Order_Count', 'Change_Cost_Ratio', 'Defect_Count', 'Defect_Severity', 'Repair_Cost', 'Accident_Count', 'Risk_Level', 'Temperature', 'Rainfall']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (80000, 19)
# X_test: (20000, 19)
# y_train: (80000,)
# y_test: (20000,)

# %%
categorical_features = X.select_dtypes(include=['object', 'str']).columns.tolist()
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

print("Categorical features:")
print(categorical_features)

print("\nNumerical features:")
print(numerical_features)

print("\nNumber of categorical features:", len(categorical_features))
print("Number of numerical features:", len(numerical_features))
# Out:
# Categorical features:
# ['Project_Type', 'Structure_Type', 'Contract_Type']
#
# Numerical features:
# ['Area', 'Floor_Count', 'Planned_Cost', 'Planned_Duration', 'Labor_Total', 'Equipment_Count', 'Resource_Utilization', 'Change_Order_Count', 'Change_Cost_Ratio', 'Defect_Count', 'Defect_Severity', 'Repair_Cost', 'Accident_Count', 'Risk_Level', 'Temperature', 'Rainfall']
#
# Number of categorical features: 3
# Number of numerical features: 16

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

print("Preprocessor created successfully.")
# Out:
# Preprocessor created successfully.

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

linear_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

print("Linear Regression pipeline created successfully.")
# Out:
# Linear Regression pipeline created successfully.

# %%
linear_model.fit(X_train, y_train)

print("Linear Regression model trained successfully.")
# Out:
# Linear Regression model trained successfully.

# %%
y_pred = linear_model.predict(X_test)

print("Predictions generated successfully.")
print("Number of predictions:", len(y_pred))
# Out:
# Predictions generated successfully.
# Number of predictions: 20000

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("Linear Regression Performance")
print("-----------------------------")
print(f"MAE:  {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R²:   {r2:.4f}")
# Out:
# Linear Regression Performance
# -----------------------------
# MAE:  0.0322
# RMSE: 0.0404
# R²:   0.8391

# %%
comparison = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred
})

print(comparison.head(10))
# Out:
#      Actual  Predicted
# 0  0.355190   0.352893
# 1  0.165552   0.252906
# 2  0.259347   0.248517
# 3  0.201159   0.274074
# 4  0.071329   0.053541
# 5  0.108100   0.125371
# 6  0.346338   0.380510
# 7  0.263983   0.287647
# 8  0.093863   0.191699
# 9  0.330296   0.238489

# %%
print(comparison.describe())
# Out:
#              Actual     Predicted
# count  20000.000000  20000.000000
# mean       0.246061      0.245647
# std        0.100737      0.092459
# min        0.017984     -0.012302
# 25%        0.169731      0.179106
# 50%        0.233102      0.238402
# 75%        0.310342      0.305936
# max        0.550000      0.670800

# %%
plt.figure(figsize=(8, 6))

plt.scatter(y_test, y_pred, alpha=0.2)

plt.xlabel('Actual Cost Overrun')
plt.ylabel('Predicted Cost Overrun')
plt.title('Actual vs Predicted Cost Overrun')

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestRegressor(
        n_estimators=100,
        random_state=42,
        n_jobs=-1
    ))
])

print("Random Forest pipeline created successfully.")
# Out:
# Random Forest pipeline created successfully.

# %%
random_forest_model.fit(X_train, y_train)

print("Random Forest model trained successfully.")
# Out:
# Random Forest model trained successfully.

# %%
rf_pred = random_forest_model.predict(X_test)

print("Predictions generated:", len(rf_pred))
# Out:
# Predictions generated: 20000

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

rf_mae = mean_absolute_error(y_test, rf_pred)
rf_rmse = np.sqrt(mean_squared_error(y_test, rf_pred))
rf_r2 = r2_score(y_test, rf_pred)

print(f"MAE:  {rf_mae:.4f}")
print(f"RMSE: {rf_rmse:.4f}")
print(f"R²:   {rf_r2:.4f}")
# Out:
# MAE:  0.0311
# RMSE: 0.0397
# R²:   0.8445

# %%
from sklearn.ensemble import GradientBoostingRegressor

gradient_boosting_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', GradientBoostingRegressor(
        n_estimators=100,
        learning_rate=0.05,
        max_depth=3,
        random_state=42
    ))
])

print("Gradient Boosting pipeline created successfully.")
# Out:
# Gradient Boosting pipeline created successfully.

# %%
gradient_boosting_model.fit(X_train, y_train)

print("Gradient Boosting model trained successfully.")
# Out:
# Gradient Boosting model trained successfully.

# %%
gb_pred = gradient_boosting_model.predict(X_test)

print("Predictions generated:", len(gb_pred))
# Out:
# Predictions generated: 20000

# %%
gb_mae = mean_absolute_error(y_test, gb_pred)
gb_rmse = np.sqrt(mean_squared_error(y_test, gb_pred))
gb_r2 = r2_score(y_test, gb_pred)

print(f"MAE:  {gb_mae:.4f}")
print(f"RMSE: {gb_rmse:.4f}")
print(f"R²:   {gb_r2:.4f}")
# Out:
# MAE:  0.0318
# RMSE: 0.0402
# R²:   0.8407

# %%
cv_scores = cross_val_score(
    random_forest_model,
    X_train,
    y_train,
    cv=5,
    scoring='r2',
    n_jobs=1
)

print("Cross-validation R² scores:")
print(cv_scores)

print(f"\nMean CV R²: {cv_scores.mean():.4f}")
print(f"Std CV R²:  {cv_scores.std():.4f}")
# Out:
# Cross-validation R² scores:
# [0.83591467 0.83615485 0.84087905 0.83992191 0.84162906]
#
# Mean CV R²: 0.8389
# Std CV R²:  0.0024

# %%
rf_model = random_forest_model.named_steps['model']

feature_names = (
    numerical_features +
    list(
        random_forest_model
        .named_steps['preprocessor']
        .named_transformers_['cat']
        .get_feature_names_out(categorical_features)
    )
)

importances = rf_model.feature_importances_

feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values('Importance', ascending=False)

print(feature_importance.head(15))
# Out:
#                     Feature  Importance
# 13               Risk_Level    0.436780
# 8         Change_Cost_Ratio    0.244019
# 18  Project_Type_Remodeling    0.065034
# 16    Project_Type_Building    0.057898
# 26        Contract_Type_DBB    0.029837
# 6      Resource_Utilization    0.026213
# 15                 Rainfall    0.022089
# 10          Defect_Severity    0.012357
# 11              Repair_Cost    0.011828
# 14              Temperature    0.011540
# 1               Floor_Count    0.008234
# 4               Labor_Total    0.008082
# 3          Planned_Duration    0.007669
# 0                      Area    0.007553
# 9              Defect_Count    0.007491

# %%
print("Risk Level vs Cost Overrun:")
print(df[['Risk_Level', 'Cost_Overrun']].corr())

print("\nChange Cost Ratio vs Cost Overrun:")
print(df[['Change_Cost_Ratio', 'Cost_Overrun']].corr())
# Out:
# Risk Level vs Cost Overrun:
#               Risk_Level  Cost_Overrun
# Risk_Level      1.000000      0.686981
# Cost_Overrun    0.686981      1.000000
#
# Change Cost Ratio vs Cost Overrun:
#                    Change_Cost_Ratio  Cost_Overrun
# Change_Cost_Ratio           1.000000      0.585893
# Cost_Overrun                0.585893      1.000000

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'model__n_estimators': [100, 200],
    'model__max_depth': [None, 10, 20],
    'model__min_samples_split': [2, 5],
    'model__min_samples_leaf': [1, 2]
}

random_search = RandomizedSearchCV(
    estimator=random_forest_model,
    param_distributions=param_grid,
    n_iter=8,
    cv=3,
    scoring='r2',
    random_state=42,
    n_jobs=1,
    verbose=1
)

print("Randomized search configured successfully.")
# Out:
# Randomized search configured successfully.

# %%
random_search.fit(X_train, y_train)

print("Random Forest hyperparameter tuning completed.")
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# D:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:489: FitFailedWarning:
# 3 fits failed out of a total of 24.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "D:\Users\User\anaconda3\Lib\site-packages\joblib\_utils.py", line 109, in __call__
#     return self.func(**kwargs)
#            ~~~~~~~~~^^^^^^^^^^
#   File "D:\Users\User\anaconda3\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
# ...

# %%
print("Best parameters:")
print(random_search.best_params_)

print(f"\nBest cross-validation R²: {random_search.best_score_:.4f}")
# Out:
# Best parameters:
# {'model__n_estimators': 100, 'model__min_samples_split': 5, 'model__min_samples_leaf': 1, 'model__max_depth': 20}
#
# Best cross-validation R²: 0.8384

# %%
best_rf_model = random_search.best_estimator_

best_rf_pred = best_rf_model.predict(X_test)

best_rf_mae = mean_absolute_error(y_test, best_rf_pred)
best_rf_rmse = np.sqrt(mean_squared_error(y_test, best_rf_pred))
best_rf_r2 = r2_score(y_test, best_rf_pred)

print(f"MAE:  {best_rf_mae:.4f}")
print(f"RMSE: {best_rf_rmse:.4f}")
print(f"R²:   {best_rf_r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[152], line 3
#       1 best_rf_model = random_search.best_estimator_
#       2
# ----> 3 best_rf_pred = best_rf_model.predict(X_test)
#       4
#       5 best_rf_mae = mean_absolute_error(y_test, best_rf_pred)
#       6 best_rf_rmse = np.sqrt(mean_squared_error(y_test, best_rf_pred))
#
# File D:\Users\User\anaconda3\Lib\site-packages\sklearn\pipeline.py:791, in Pipeline.predict(self, X, **params)
#     748 @available_if(_final_estimator_has("predict"))
#     749 def predict(self, X, **params):
#     750     """Transform the data, and apply `predict` with the final estimator.
#     751
#     752     Call `transform` of each transformer in the pipeline. The transformed
#    (...)    789         Result of calling `predict` on the final estimator.
#     790     """
# --> 791     check_is_fitted(self)
#     792     Xt = X
# ...

# %%
residuals = y_test - best_rf_pred

print("Residual analysis created successfully.")
print(f"Mean residual: {residuals.mean():.4f}")
print(f"Minimum residual: {residuals.min():.4f}")
print(f"Maximum residual: {residuals.max():.4f}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.scatter(best_rf_pred, residuals, alpha=0.3)

plt.axhline(y=0, linestyle='--')

plt.xlabel("Predicted Cost Overrun")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual Plot — Tuned Random Forest")

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_test, best_rf_pred, alpha=0.3)

plt.xlabel("Actual Cost Overrun")
plt.ylabel("Predicted Cost Overrun")
plt.title("Actual vs Predicted Cost Overrun — Tuned Random Forest")

plt.show()

# %%
import joblib

joblib.dump(best_rf_model, 'construction_cost_overrun_model.pkl')

print("Final model saved successfully.")
# Out:
# Final model saved successfully.

# %%
import joblib

loaded_model = joblib.load('construction_cost_overrun_model.pkl')

test_predictions = loaded_model.predict(X_test.head(5))

print("Saved model loaded successfully.")
print("Test predictions:", test_predictions)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[154], line 5
#       1 import joblib
#       2
#       3 loaded_model = joblib.load('construction_cost_overrun_model.pkl')
#       4
# ----> 5 test_predictions = loaded_model.predict(X_test.head(5))
#       6
#       7 print("Saved model loaded successfully.")
#       8 print("Test predictions:", test_predictions)
#
# File D:\Users\User\anaconda3\Lib\site-packages\sklearn\pipeline.py:791, in Pipeline.predict(self, X, **params)
#     748 @available_if(_final_estimator_has("predict"))
#     749 def predict(self, X, **params):
#     750     """Transform the data, and apply `predict` with the final estimator.
#     751
#     752     Call `transform` of each transformer in the pipeline. The transformed
#    (...)    789         Result of calling `predict` on the final estimator.
#     790     """
# ...

# %%
final_model = random_search.best_estimator_

final_model.fit(X_train, y_train)

print("Final model fitted successfully.")
# Out:
# Final model fitted successfully.

# %%
import joblib

joblib.dump(final_model, 'construction_cost_overrun_model.pkl')

print("Final fitted model saved successfully.")
# Out:
# Final fitted model saved successfully.

# %%
loaded_model = joblib.load('construction_cost_overrun_model.pkl')

test_predictions = loaded_model.predict(X_test.head(5))

print("Saved model loaded successfully.")
print("Test predictions:")
print(test_predictions)
# Out:
# Saved model loaded successfully.
# Test predictions:
# [0.36067629 0.25116691 0.19941243 0.28636971 0.08024349]
